# %%
from positionalembedding2d import positionalencoding1d, positionalencoding2d
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
pe = positionalencoding1d(128, 100)
plt.figure(figsize=(15, 5))
plt.plot(np.arange(100), pe[:,0:63:16])
plt.legend(["dim %d"%p for p in [4,5,6,7]])

# %%
pe2 = positionalencoding2d(128,100,100)

plt.subplot(221)
plt.imshow(pe2[0,:,:])
plt.subplot(222)
plt.imshow(pe2[63,:,:])
plt.subplot(223)
plt.imshow(pe2[64,:,:])
plt.subplot(224)
plt.imshow(pe2[127,:,:])

# %%
pe2[127,:,:]
# Out:
# array([[1.        , 1.        , 1.        , ..., 1.        , 1.        ,
#         1.        ],
#        [0.99999999, 0.99999999, 0.99999999, ..., 0.99999999, 0.99999999,
#         0.99999999],
#        [0.99999996, 0.99999996, 0.99999996, ..., 0.99999996, 0.99999996,
#         0.99999996],
#        ...,
#        [0.99991634, 0.99991634, 0.99991634, ..., 0.99991634, 0.99991634,
#         0.99991634],
#        [0.99991461, 0.99991461, 0.99991461, ..., 0.99991461, 0.99991461,
#         0.99991461],
#        [0.99991286, 0.99991286, 0.99991286, ..., 0.99991286, 0.99991286,
#         0.99991286]])
